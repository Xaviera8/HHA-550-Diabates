# %% [markdown]
# # Import Data and Packages

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('diabetic_data.csv')

# %% [markdown]
# # Check for Missingness

# %%
df.sample(5)
# Out:
#        encounter_id  patient_nbr             race  gender      age weight  \
# 5928       30065346      3739176        Caucasian    Male  [70-80)      ?
# 5329       27995694     23745006        Caucasian  Female  [50-60)      ?
# 25491      85075254     16251984        Caucasian    Male  [30-40)      ?
# 15350      58999098    109551240        Caucasian  Female  [60-70)      ?
# 39308     122350140     23879781  AfricanAmerican    Male  [70-80)      ?
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 5928                   3                         1                    1
# 5329                   5                         6                   17
# 25491                  3                         1                    2
# 15350                  6                         1                    7
# 39308                  1                        13                    7
#
#        time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
readmitted_mapping = {'NO': 'Patient did not readmit', '>30': 'Greater than 30 Days', '<30': 'Within 30 Days'}
df = df.replace({"readmitted": readmitted_mapping})
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
readmission_mapping = {'>30': 'Greater than 30 Days', '<30': 'Less than 30 Days'}
df.replace({'readmitted': readmission_mapping})
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
df.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# ...

# %% [markdown]
# ### It appears that the dataset uses "?" to represent missing values. I will replace the "?" with NA to make checking for missingness easier.

# %%
df.replace('?', pd.NA, inplace=True)

def missing (df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values

missing(df)
# Out:
#                           Missing_Number  Missing_Percent
# weight                             98569         0.968585
# medical_specialty                  49949         0.490822
# payer_code                         40256         0.395574
# race                                2273         0.022336
# diag_3                              1423         0.013983
# diag_2                               358         0.003518
# diag_1                                21         0.000206
# encounter_id                           0         0.000000
# tolazamide                             0         0.000000
# glyburide                              0         0.000000
# tolbutamide                            0         0.000000
# pioglitazone                           0         0.000000
# rosiglitazone                          0         0.000000
# acarbose                               0         0.000000
# miglitol                               0         0.000000
# ...

# %% [markdown]
# # Check for Duplicates

# %%
df['encounter_id'].duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
fig = px.histogram(df, x="readmitted", title='30 Day Patient Readmission Rates',   width=500, height=500, labels={"readmitted": 'Readmissions'
                   })
fig.show()
